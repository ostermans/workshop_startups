# %% [markdown]
# # Предсказание стартапов

# %% [markdown]
# В проекте разработана модель машинного обучения для предсказания статуса деятельности стартапа. Проведена обработка данных, разведочный анализ, обнаружены признаки влияющие на успешность стартапа.

# %% [markdown]
# ## Загрузка и ознакомление с данными

# %% [markdown]
# Предоставленный для проекта датасет состоит из двух файлов (+пример с выгрузкой): тренировочный набор (около 53к записей) и тестовый набор (около 13к записей). Тренировочный набор содержит целевой признак status, указывающий на то, закрылся стартап или продолжает действовать. Временной период - '1970-01-01' по '2018-01-01'. Дата формирования выгрузки - '2018-01-01'

# %% [markdown]
# * kaggle_startups_train.csv - информация (53 000) стартапах, которые будут использоваться в качестве обучающих данных.
# * kaggle_startups_test.csv - информация (13 000) стартапах, которые будут использоваться в качестве тестовых данных. Ваша задача - предсказать значение 'status' для каждого стартапа из этого датасета.
# * kaggle_startups_sample_submit.csv - файл с примером предсказаний в правильном формате.
# * name - идентификатор (название) стартапа в тестовом наборе.
# * status - целевой признак. Для каждого стартапа предскажите категориальное значение соответствующее прогнозу ['operating', 'closed'].

# %%
# !pip install phik -q
# !pip install catboost -q
# !pip install shap -q

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
    MinMaxScaler,
    LabelEncoder
)
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from catboost import CatBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score

import joblib
import phik
import time
import shap

# %%
try:
    train = pd.read_csv('kaggle_startups_train_28062024.csv')
    test = pd.read_csv('kaggle_startups_test_28062024.csv')
    sample = pd.read_csv('kaggle_startups_sample_submit_28062024.csv')

except:
    train = pd.read_csv('datasets/kaggle_startups_train_28062024.csv')
    test = pd.read_csv('datasets/kaggle_startups_test_28062024.csv')
    sample = pd.read_csv('datasets/kaggle_startups_sample_submit_28062024.csv')

# %%
 def data_head_desc_info(data):
    try:
        display('Первые 3 строки:')
        display(data.head(3))
        display('Описание данных:')
        display(data.describe(include = "all"))
        display('Общая информацию о датафрейме')
        display(data.info())
        display('Количество пропусков')
        display(data.isna().sum())
    except:
        return 'Проверьте параметры'

# %% [markdown]
# ### train

# %%
data_head_desc_info(train)
# Out:
# 'Первые 3 строки:'
#                      name                          category_list  \
# 0               Lunchgate        Online Reservations|Restaurants
# 1                 EarLens  Manufacturing|Medical|Medical Devices
# 2  Reviva Pharmaceuticals                          Biotechnology
#
#    funding_total_usd     status country_code state_code       region  \
# 0           828626.0  operating          CHE         25       Zurich
# 1         42935019.0  operating          USA         CA  SF Bay Area
# 2         35456381.0  operating          USA         CA  SF Bay Area
#
#            city  funding_rounds  founded_at first_funding_at last_funding_at  \
# 0        Zürich               2  2009-10-17       2011-05-01      2014-12-01
# 1  Redwood City               4  2005-01-01       2010-05-04      2014-02-25
# 2      San Jose               3  2006-01-01       2012-08-20      2014-07-02
#
#   closed_at
# 0       NaN
# 1       NaN
# 2       NaN
# 'Описание данных:'
#              name category_list  funding_total_usd     status country_code  \
# count       52515         50051       4.244700e+04      52516        47014
# unique      52515         22105                NaN          2          134
# top     Lunchgate      Software                NaN  operating          USA
# freq            1          3207                NaN      47599        29702
# mean          NaN           NaN       1.824748e+07        NaN          NaN
# std           NaN           NaN       1.871173e+08        NaN          NaN
# min           NaN           NaN       1.000000e+00        NaN          NaN
# 25%           NaN           NaN       3.360275e+05        NaN          NaN
# 50%           NaN           NaN       2.000000e+06        NaN          NaN
# 75%           NaN           NaN       1.000000e+07        NaN          NaN
# max           NaN           NaN       3.007950e+10        NaN          NaN
#
#        state_code       region           city  funding_rounds  founded_at  \
# count       45753        46157          46157    52516.000000       52516
# unique        300         1036           4477             NaN        5402
# top            CA  SF Bay Area  San Francisco             NaN  2012-01-01
# freq        10219         6970           2824             NaN        2171
# mean          NaN          NaN            NaN        1.740670         NaN
# std           NaN          NaN            NaN        1.374522         NaN
# min           NaN          NaN            NaN        1.000000         NaN
# 25%           NaN          NaN            NaN        1.000000         NaN
# 50%           NaN          NaN            NaN        1.000000         NaN
# 75%           NaN          NaN            NaN        2.000000         NaN
# max           NaN          NaN            NaN       19.000000         NaN
#
#        first_funding_at last_funding_at   closed_at
# count             52516           52516        4917
# unique             4603            4305        3008
# top          2013-01-01      2014-01-01  2016-12-02
# freq                450             369           8
# mean                NaN             NaN         NaN
# std                 NaN             NaN         NaN
# min                 NaN             NaN         NaN
# 25%                 NaN             NaN         NaN
# 50%                 NaN             NaN         NaN
# 75%                 NaN             NaN         NaN
# max                 NaN             NaN         NaN
# 'Общая информацию о датафрейме'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52515 non-null  object
#  1   category_list      50051 non-null  object
#  2   funding_total_usd  42447 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       47014 non-null  object
#  5   state_code         45753 non-null  object
#  6   region             46157 non-null  object
#  7   city               46157 non-null  object
#  8   funding_rounds     52516 non-null  int64
#  9   founded_at         52516 non-null  object
#  10  first_funding_at   52516 non-null  object
#  11  last_funding_at    52516 non-null  object
#  12  closed_at          4917 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 5.2+ MB
# None
# 'Количество пропусков'
# name                     1
# category_list         2465
# funding_total_usd    10069
# status                   0
# country_code          5502
# state_code            6763
# region                6359
# city                  6359
# funding_rounds           0
# founded_at               0
# first_funding_at         0
# last_funding_at          0
# closed_at            47599
# dtype: int64

# %% [markdown]
# ### test

# %%
data_head_desc_info(test)
# Out:
# 'Первые 3 строки:'
#                name     category_list  funding_total_usd country_code  \
# 0        Crystalsol  Clean Technology          2819200.0          NIC
# 1  JBI Fish & Wings       Hospitality                NaN          USA
# 2          COINPLUS           Finance           428257.0          LUX
#
#   state_code            region              city  funding_rounds  \
# 0         17               NaN               NaN               1
# 1         TN        TN - Other          Humboldt               1
# 2          3  Esch-sur-alzette  Esch-sur-alzette               2
#
#   first_funding_at last_funding_at  lifetime
# 0       2009-07-01      2009-07-01      3501
# 1       2010-07-28      2010-07-28      2717
# 2       2014-05-15      2014-09-18      1295
# 'Описание данных:'
#               name category_list  funding_total_usd country_code state_code  \
# count        13125         12534       1.054700e+04        11743      11430
# unique       13125          6206                NaN           96        235
# top     Crystalsol      Software                NaN          USA         CA
# freq             1           775                NaN         7428       2552
# mean           NaN           NaN       1.654910e+07          NaN        NaN
# std            NaN           NaN       9.217283e+07          NaN        NaN
# min            NaN           NaN       1.000000e+00          NaN        NaN
# 25%            NaN           NaN       3.200000e+05          NaN        NaN
# 50%            NaN           NaN       2.000000e+06          NaN        NaN
# 75%            NaN           NaN       1.000000e+07          NaN        NaN
# max            NaN           NaN       4.715000e+09          NaN        NaN
#
#              region           city  funding_rounds first_funding_at  \
# count         11536          11538    13125.000000            13125
# unique          688           2117             NaN             3299
# top     SF Bay Area  San Francisco             NaN       2014-01-01
# freq           1750            656             NaN              126
# mean            NaN            NaN        1.714438              NaN
# std             NaN            NaN        1.318800              NaN
# min             NaN            NaN        1.000000              NaN
# 25%             NaN            NaN        1.000000              NaN
# 50%             NaN            NaN        1.000000              NaN
# 75%             NaN            NaN        2.000000              NaN
# max             NaN            NaN       15.000000              NaN
#
#        last_funding_at      lifetime
# count            13125  13125.000000
# unique            3021           NaN
# top         2014-01-01           NaN
# freq               111           NaN
# mean               NaN   3097.609524
# std                NaN   2128.356554
# min                NaN     52.000000
# 25%                NaN   1726.000000
# 50%                NaN   2526.000000
# 75%                NaN   3866.000000
# max                NaN  17167.000000
# 'Общая информацию о датафрейме'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13125 non-null  object
#  1   category_list      12534 non-null  object
#  2   funding_total_usd  10547 non-null  float64
#  3   country_code       11743 non-null  object
#  4   state_code         11430 non-null  object
#  5   region             11536 non-null  object
#  6   city               11538 non-null  object
#  7   funding_rounds     13125 non-null  int64
#  8   first_funding_at   13125 non-null  object
#  9   last_funding_at    13125 non-null  object
#  10  lifetime           13125 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.1+ MB
# None
# 'Количество пропусков'
# name                    0
# category_list         591
# funding_total_usd    2578
# country_code         1382
# state_code           1695
# region               1589
# city                 1587
# funding_rounds          0
# first_funding_at        0
# last_funding_at         0
# lifetime                0
# dtype: int64

# %% [markdown]
# ### sample

# %%
data_head_desc_info(sample)
# Out:
# 'Первые 3 строки:'
#                name     status
# 0        Crystalsol     closed
# 1  JBI Fish & Wings  operating
# 2          COINPLUS     closed
# 'Описание данных:'
#               name     status
# count        13125      13125
# unique       13125          2
# top     Crystalsol  operating
# freq             1       6635
# 'Общая информацию о датафрейме'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    13125 non-null  object
#  1   status  13125 non-null  object
# dtypes: object(2)
# memory usage: 205.2+ KB
# None
# 'Количество пропусков'
# name      0
# status    0
# dtype: int64

# %% [markdown]
# `train`- тренировочный датасет содержит 52516 строк.
#
# Столбцы:
#
# `name`  - название стартапа, все названия уникальны
# `category_list` - категория. Более 22тыс. уникальных значений.
# `funding_total_usd`  - финансирование стартапа в долларах
# `status ` - статус действует или закрыт (целевой признак)
#
# `country_code` - код страны
#
# `state_code` - код штата
#
# `region` - регион
#
# `city` - город
#
# `funding_rounds` - число раундов финансирования
#
# `founded_at` - дата основания
#
# `first_funding_at` - дата первого финансирования
#
# `last_funding_at` - дата последнего финансирования
#
# `closed_at` - дата закрытия
#
# Большое число пропусков и слишком большое число уникальных значений в категориальных столбцах. Тип данных столбцов с датой не соответствует дате.
#
# ---
# `test`
#
# Содержит похожий набор признаков, нет целевого `status`, который для проверки находится в датасете sample. Есть признак lifetime, логично отсутствует closed_at, founded_at. Есть пропуски и большое число уникальных категорий.

# %% [markdown]
# ## Предварительная обработка

# %% [markdown]
# ### Тип данных

# %% [markdown]
# Приведем даты к соответствующему типу в тренировочном и тестовом датафреймах.

# %%
train['founded_at'] = pd.to_datetime(train['founded_at'])
train['first_funding_at'] = pd.to_datetime(train['first_funding_at'])
train['last_funding_at'] = pd.to_datetime(train['last_funding_at'])
train['closed_at'] = pd.to_datetime(train['closed_at'])

display(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52515 non-null  object
#  1   category_list      50051 non-null  object
#  2   funding_total_usd  42447 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       47014 non-null  object
#  5   state_code         45753 non-null  object
#  6   region             46157 non-null  object
#  7   city               46157 non-null  object
#  8   funding_rounds     52516 non-null  int64
#  9   founded_at         52516 non-null  datetime64[ns]
#  10  first_funding_at   52516 non-null  datetime64[ns]
#  11  last_funding_at    52516 non-null  datetime64[ns]
#  12  closed_at          4917 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), float64(1), int64(1), object(7)
# memory usage: 5.2+ MB
# None

# %%
test['first_funding_at'] = pd.to_datetime(test['first_funding_at'])
test['last_funding_at'] = pd.to_datetime(test['last_funding_at'])

display(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13125 non-null  object
#  1   category_list      12534 non-null  object
#  2   funding_total_usd  10547 non-null  float64
#  3   country_code       11743 non-null  object
#  4   state_code         11430 non-null  object
#  5   region             11536 non-null  object
#  6   city               11538 non-null  object
#  7   funding_rounds     13125 non-null  int64
#  8   first_funding_at   13125 non-null  datetime64[ns]
#  9   last_funding_at    13125 non-null  datetime64[ns]
#  10  lifetime           13125 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(6)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# ### Уникальные значения

# %% [markdown]
# #### category_list

# %%
train['category_list'].value_counts().head(5)
# Out:
# category_list
# Software            3207
# Biotechnology       2905
# E-Commerce          1064
# Mobile               920
# Clean Technology     892
# Name: count, dtype: int64

# %%
train['category_list'].value_counts().tail(5)
# Out:
# category_list
# iPad|Reviews and Recommendations|Social Television|Software|Television|Video on Demand    1
# Graphics|Software|Startups                                                                1
# Curated Web|File Sharing|Graphics|PaaS                                                    1
# Cloud Computing|Cloud Data Services|Databases|IaaS|Services|Software|Virtualization       1
# Online Rental|Parking|Price Comparison                                                    1
# Name: count, dtype: int64

# %%
train['category_list'].value_counts().count()
# Out:
# 22105

# %% [markdown]
# Сократим число категориальных значений для столбца с Категориями. Много категорий представлены списком. Возьмем из каждого уникального значения категории только первое значение из списка. Повторим для обоих датафреймов

# %%
train['category_first'] = train['category_list'].str.split('|').str[0]
#display(train['category_first'].value_counts().head(60))
display(train['category_first'].value_counts().count())
# Out:
# 707

# %%
test['category_first'] = test['category_list'].str.split('|').str[0]
#display(train['category_first'].value_counts().head(60))
display(test['category_first'].value_counts().count())
# Out:
# 559

# %% [markdown]
# #### country_code

# %%
train['country_code'].value_counts().count()
# Out:
# 134

# %%
unique_codes = train['country_code'].unique()
unique_codes
# Out:
# array(['CHE', 'USA', nan, 'GBR', 'RUS', 'ESP', 'FRA', 'SWE', 'IND', 'KOR',
#        'AUS', 'TWN', 'CHN', 'HUN', 'CAN', 'FIN', 'BRA', 'EGY', 'PRT',
#        'ISR', 'CHL', 'SVK', 'NLD', 'ARG', 'ARE', 'JPN', 'IRL', 'DEU',
#        'LBN', 'EST', 'IDN', 'BEL', 'MEX', 'DNK', 'ITA', 'GRC', 'ROM',
#        'TUR', 'SGP', 'SAU', 'MYS', 'NGA', 'QAT', 'VNM', 'BGR', 'GHA',
#        'UGA', 'JOR', 'AUT', 'PAK', 'NZL', 'HKG', 'ZAF', 'LVA', 'NOR',
#        'HRV', 'VEN', 'PER', 'LUX', 'SVN', 'POL', 'PHL', 'NIC', 'CZE',
#        'ISL', 'PAN', 'URY', 'BGD', 'MCO', 'GTM', 'THA', 'TTO', 'UKR',
#        'KEN', 'CRI', 'DZA', 'LTU', 'CYM', 'MUS', 'BLR', 'SLV', 'COL',
#        'MLT', 'PSE', 'BLZ', 'CYP', 'MMR', 'MKD', 'KHM', 'GIB', 'SRB',
#        'DOM', 'BWA', 'BLM', 'PRY', 'BMU', 'TAN', 'LIE', 'GRD', 'UZB',
#        'GEO', 'SEN', 'ALB', 'ECU', 'MOZ', 'LKA', 'LAO', 'TUN', 'HND',
#        'ZWE', 'BAH', 'MDA', 'MAF', 'BHR', 'AZE', 'MAR', 'KWT', 'IRN',
#        'GGY', 'KNA', 'PRI', 'OMN', 'KAZ', 'JAM', 'NPL', 'ARM', 'TGO',
#        'RWA', 'BRN', 'JEY', 'SOM', 'CMR', 'MNE', 'SYC', 'ZMB'],
#       dtype=object)

# %%
train['region'].value_counts().count()
# Out:
# 1036

# %%
train['status'].value_counts()
# Out:
# status
# operating    47599
# closed        4917
# Name: count, dtype: int64

# %% [markdown]
# ### Дубликаты

# %%
display('Дубликаты в таблице train',
        train.duplicated().sum())
display('Дубликаты name в train',
        train.duplicated(subset=['name']).sum())
display('Дубликаты без имени в таблице train',
        train.drop('name', axis=1).duplicated().sum())
# Out:
# 'Дубликаты в таблице train'
# 0
# 'Дубликаты name в train'
# 0
# 'Дубликаты без имени в таблице train'
# 10

# %%
train = train.loc[~train.drop('name', axis=1).duplicated()]

display('Дубликаты без имени в таблице train',
        train.drop('name', axis=1).duplicated().sum())
# Out:
# 'Дубликаты без имени в таблице train'
# 0

# %% [markdown]
# ### Пропуски train

# %% [markdown]
# #### founded_at

# %% [markdown]
# Выделим в отдельные столбцы год, месяц, день, день недели создания стартапа. В тестовом датафрейме этого столбца нет. Поэтому сможем использовать эти данные только для анализа и заполнения пропусков в других столбцах.

# %%
train['founded_at_year'] = train['founded_at'].dt.year
train['founded_at_month'] = train['founded_at'].dt.month
train['founded_at_day'] = train['founded_at'].dt.day
train['founded_at_dayofweek'] = train['founded_at'].dt.dayofweek

train.head(1)
# Out:
#         name                    category_list  funding_total_usd     status  \
# 0  Lunchgate  Online Reservations|Restaurants           828626.0  operating
#
#   country_code state_code  region    city  funding_rounds founded_at  \
# 0          CHE         25  Zurich  Zürich               2 2009-10-17
#
#   first_funding_at last_funding_at closed_at       category_first  \
# 0       2011-05-01      2014-12-01       NaT  Online Reservations
#
#    founded_at_year  founded_at_month  founded_at_day  founded_at_dayofweek
# 0             2009                10              17                     5

# %%
display(train.isna().sum())
# Out:
# name                        1
# category_list            2457
# funding_total_usd       10061
# status                      0
# country_code             5496
# state_code               6757
# region                   6353
# city                     6353
# funding_rounds              0
# founded_at                  0
# first_funding_at            0
# last_funding_at             0
# closed_at               47589
# category_first           2457
# founded_at_year             0
# founded_at_month            0
# founded_at_day              0
# founded_at_dayofweek        0
# dtype: int64

# %% [markdown]
# #### name

# %%
train[train['name'].isna()]
# Out:
#      name category_list  funding_total_usd  status country_code state_code  \
# 3291  NaN      Startups            25000.0  closed          USA         OR
#
#                 region      city  funding_rounds founded_at first_funding_at  \
# 3291  Portland, Oregon  Portland               1 2011-10-01       2012-03-01
#
#      last_funding_at  closed_at category_first  founded_at_year  \
# 3291      2012-03-01 2013-06-03       Startups             2011
#
#       founded_at_month  founded_at_day  founded_at_dayofweek
# 3291                10               1                     5

# %%
train['name'].fillna('Noname', inplace=True)

# %% [markdown]
# #### country_code, state_code, region, city

# %%
display(train.isna().sum())
# Out:
# name                        0
# category_list            2457
# funding_total_usd       10061
# status                      0
# country_code             5496
# state_code               6757
# region                   6353
# city                     6353
# funding_rounds              0
# founded_at                  0
# first_funding_at            0
# last_funding_at             0
# closed_at               47589
# category_first           2457
# founded_at_year             0
# founded_at_month            0
# founded_at_day              0
# founded_at_dayofweek        0
# dtype: int64

# %%
display("Число строк с пропуском в country_code и не пропуском в region")
display(train[(train['country_code'].isna()) & (train['region'].notna())].count())
# Out:
# 'Число строк с пропуском в country_code и не пропуском в region'
# name                    0
# category_list           0
# funding_total_usd       0
# status                  0
# country_code            0
# state_code              0
# region                  0
# city                    0
# funding_rounds          0
# founded_at              0
# first_funding_at        0
# last_funding_at         0
# closed_at               0
# category_first          0
# founded_at_year         0
# founded_at_month        0
# founded_at_day          0
# founded_at_dayofweek    0
# dtype: int64

# %%
display("Число строк с пропуском в country_code и не пропуском в state_code")
display(train[(train['country_code'].isna()) & (train['state_code'].notna())].count())
# Out:
# 'Число строк с пропуском в country_code и не пропуском в state_code'
# name                    0
# category_list           0
# funding_total_usd       0
# status                  0
# country_code            0
# state_code              0
# region                  0
# city                    0
# funding_rounds          0
# founded_at              0
# first_funding_at        0
# last_funding_at         0
# closed_at               0
# category_first          0
# founded_at_year         0
# founded_at_month        0
# founded_at_day          0
# founded_at_dayofweek    0
# dtype: int64

# %%
display("Число строк с пропуском в country_code и не пропуском в city")
display(train[(train['country_code'].isna()) & (train['city'].notna())].count())
# Out:
# 'Число строк с пропуском в country_code и не пропуском в city'
# name                    0
# category_list           0
# funding_total_usd       0
# status                  0
# country_code            0
# state_code              0
# region                  0
# city                    0
# funding_rounds          0
# founded_at              0
# first_funding_at        0
# last_funding_at         0
# closed_at               0
# category_first          0
# founded_at_year         0
# founded_at_month        0
# founded_at_day          0
# founded_at_dayofweek    0
# dtype: int64

# %% [markdown]
# Пропуски в столбцах страна, штат, город, регион практически совпадают по строкам и заполнить их друг от друга не получится.

# %%
train[train['country_code'].isna()].describe(include = "all")
# Out:
#                         name category_list  funding_total_usd     status  \
# count                   5496          4297       3.676000e+03       5496
# unique                  5496          2732                NaN          2
# top     Sancilio and Company      Software                NaN  operating
# freq                       1           149                NaN       4210
# mean                     NaN           NaN       1.329699e+07        NaN
# min                      NaN           NaN       6.300000e+01        NaN
# 25%                      NaN           NaN       8.062775e+04        NaN
# 50%                      NaN           NaN       5.000000e+05        NaN
# 75%                      NaN           NaN       4.525000e+06        NaN
# max                      NaN           NaN       1.066494e+10        NaN
# std                      NaN           NaN       1.992200e+08        NaN
#
#        country_code state_code region city  funding_rounds  \
# count             0          0      0    0     5496.000000
# unique            0          0      0    0             NaN
# top             NaN        NaN    NaN  NaN             NaN
# freq            NaN        NaN    NaN  NaN             NaN
# mean            NaN        NaN    NaN  NaN        1.252729
# min             NaN        NaN    NaN  NaN        1.000000
# 25%             NaN        NaN    NaN  NaN        1.000000
# 50%             NaN        NaN    NaN  NaN        1.000000
# 75%             NaN        NaN    NaN  NaN        1.000000
# max             NaN        NaN    NaN  NaN       11.000000
# std             NaN        NaN    NaN  NaN        0.710247
#
#                            founded_at               first_funding_at  \
# count                            5496                           5496
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean    2010-03-07 05:49:46.899563264  2011-10-24 17:56:19.912663552
# min               1970-02-05 00:00:00            1982-03-20 00:00:00
# 25%               2008-04-27 06:00:00            2010-03-06 12:00:00
# 50%               2012-01-01 00:00:00            2013-05-30 00:00:00
# 75%               2013-09-11 06:00:00            2014-10-14 00:00:00
# max               2016-04-02 00:00:00            2015-12-04 00:00:00
# std                               NaN                            NaN
#
#                       last_funding_at                      closed_at  \
# count                            5496                           1286
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean    2012-02-07 20:30:07.860261888  2012-08-24 04:41:03.452566272
# min               1982-03-20 00:00:00            1983-10-06 00:00:00
# 25%               2010-08-11 00:00:00            2009-10-02 00:00:00
# 50%               2013-10-10 00:00:00            2014-10-12 00:00:00
# 75%               2015-01-01 00:00:00            2016-08-25 18:00:00
# max               2015-12-04 00:00:00            2017-10-11 00:00:00
# std                               NaN                            NaN
#
#        category_first  founded_at_year  founded_at_month  founded_at_day  \
# count            4297      5496.000000       5496.000000     5496.000000
# unique            445              NaN               NaN             NaN
# top              Apps              NaN               NaN             NaN
# freq              208              NaN               NaN             NaN
# mean              NaN      2009.800582          5.258188       10.156477
# min               NaN      1970.000000          1.000000        1.000000
# 25%               NaN      2008.000000          1.000000        1.000000
# 50%               NaN      2012.000000          5.000000        7.000000
# 75%               NaN      2013.000000          9.000000       18.000000
# max               NaN      2016.000000         12.000000       31.000000
# std               NaN         5.202985          3.734760        9.837621
#
#         founded_at_dayofweek
# count            5496.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean                2.951783
# min                 0.000000
# 25%                 1.000000
# 50%                 3.000000
# 75%                 5.000000
# max                 6.000000
# std                 1.981636

# %% [markdown]
# Заполним пропуски в столбце Страна с помощью машинного обучения. Для входных данных используем столбцы без пропусков.

# %%
features = train.drop(columns=['name',
                               'country_code',
                                'state_code',
                                'region',
                                'city',
                                'status',
                                'closed_at',
                                'funding_total_usd'], axis=1).select_dtypes(include=[np.number])
target = train['country_code']

# %%
features.isna().sum()
# Out:
# funding_rounds          0
# founded_at_year         0
# founded_at_month        0
# founded_at_day          0
# founded_at_dayofweek    0
# dtype: int64

# %%
X_train_country_code = features[target.notna()]
y_train_country_code = target[target.notna()]
X_test_country_code = features[target.isna()]

# %%
# Модель
clf = RandomForestClassifier()
clf.fit(X_train_country_code, y_train_country_code)
# Out:
# RandomForestClassifier()

# %%
# Прогнозирование
predicted_countries = clf.predict(X_test_country_code)
np.array(np.unique(predicted_countries, return_counts=True)).T
# Out:
# array([['ARE', 2],
#        ['AUS', 7],
#        ['AUT', 1],
#        ['BEL', 2],
#        ['BGD', 1],
#        ['BGR', 2],
#        ['BRA', 6],
#        ['CAN', 36],
#        ['CHE', 7],
#        ['CHL', 3],
#        ['CHN', 43],
#        ['CZE', 2],
#        ['DEU', 40],
#        ['DNK', 6],
#        ['EGY', 2],
#        ['ESP', 20],
#        ['EST', 1],
#        ['FIN', 2],
#        ['FRA', 35],
#        ['GBR', 106],
#        ['GRC', 1],
#        ['HKG', 4],
#        ['HRV', 1],
#        ['IND', 59],
#        ['IRL', 8],
#        ['ISL', 1],
#        ['ISR', 9],
#        ['ITA', 13],
#        ['JPN', 12],
#        ['KOR', 9],
#        ['LUX', 2],
#        ['MEX', 8],
#        ['MKD', 1],
#        ['MOZ', 1],
#        ['MYS', 1],
#        ['NGA', 1],
#        ['NLD', 14],
#        ['NOR', 1],
#        ['NZL', 7],
#        ['PER', 1],
#        ['POL', 4],
#        ['RUS', 17],
#        ['SAU', 1],
#        ['SEN', 1],
#        ['SGP', 6],
#        ['SWE', 11],
#        ['THA', 2],
#        ['TUR', 4],
#        ['TWN', 3],
#        ['USA', 4964],
#        ['ZAF', 5]], dtype=object)

# %%
train.loc[train['country_code'].isna(), 'country_code'] = predicted_countries

# %%
columns_to_check = ['country_code', 'state_code', 'region', 'city']

# %%
for column in columns_to_check:
    missing_percentage = (train[column].isna().sum() / len(train) * 100)
    display(f"Процент пропусков в {column}: {missing_percentage:.2f}%")
# Out:
# 'Процент пропусков в country_code: 0.00%'
# 'Процент пропусков в state_code: 12.87%'
# 'Процент пропусков в region: 12.10%'
# 'Процент пропусков в city: 12.10%'

# %% [markdown]
# Теперь, зная страну, возьмем самое популярное значение для заполнения столбцов Штат, Регион, Город.

# %%
# Функция для заполнения пропусков самым популярным значением в каждой странее
def fill_missing_with_mode(series):
    mode = series.mode()
    if not mode.empty:
        # Проверка первого значения моды
        if pd.isna(mode[0]):
            # Если первое значение NaN, проверяем второе значение
            if len(mode) > 1:
                return series.fillna(mode[1])
            else:
                # Если второго значения нет, заполняем модой всех данных
                return series.fillna(overall_mode_value)
        else:
            return series.fillna(mode[0])
    return series

# %%
train['state_code'] = train.groupby('country_code')['state_code'].transform(fill_missing_with_mode)

# %%
# Штаты есть не во всех странах, поэтому пропуски в столбце Штат заполним конкретным значением
train['state_code'] = train['state_code'].fillna('nostate')

# %%
train['region'] = train.groupby('country_code')['region'].transform(fill_missing_with_mode)

# %%
train['city'] = train.groupby('region')['city'].transform(fill_missing_with_mode)

# %%
for column in columns_to_check:
    missing_percentage = (train[column].isna().sum() / len(train) * 100)
    display(f"Процент пропусков в {column}: {missing_percentage:.2f}%")
# Out:
# 'Процент пропусков в country_code: 0.00%'
# 'Процент пропусков в state_code: 0.00%'
# 'Процент пропусков в region: 0.01%'
# 'Процент пропусков в city: 0.01%'

# %%
train = train.dropna(subset=['region', 'city'])

# %% [markdown]
# #### category_list

# %% [markdown]
# Пропуски в столбце Категории заполним с помощью ранее созданной функции. Возьмем самаую популярную категорию в стране

# %%
display(
    f"Процент пропусков в категориях: "
    f"{(train['category_list'].isna().sum() / len(train) * 100):.2f}%"
)
# Out:
# 'Процент пропусков в категориях: 4.68%'

# %%
train['category_list'] = train.groupby('country_code')['category_list'].transform(fill_missing_with_mode)

# %%
display(
    f"Процент пропусков в категориях: "
    f"{(train['category_list'].isna().sum() / len(train) * 100):.2f}%"
)
# Out:
# 'Процент пропусков в категориях: 0.00%'

# %% [markdown]
# #### category_first

# %%
#train['city'] = train.groupby('region')['city'].transform(fill_missing_with_mode)

# %%
train['category_first'] = train.groupby('country_code')['category_first'].transform(fill_missing_with_mode)
train['category_first'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### closed_at

# %% [markdown]
# Проверим пропуски в столбце closed_at для стартапов, которые имеют статус Закрыт. Если для таких строк нет пропусков, значит пропуск значит, что стартап не закрывался, поэтому дата закрытия не заполнена.

# %%
display("Число случайных пропусков в столбце closed_at")
train[train['status'] == 'closed']['closed_at'].isna().sum()
# Out:
# 'Число случайных пропусков в столбце closed_at'
# 0

# %% [markdown]
# #### funding_total_usd

# %% [markdown]
# Пропуски в столбце финансирования заполним своей медианой для каждой категории. Если для категории медианы нет, заполним общей медианой.
# Медиану используем как величину, более устойчивую к наличию выбросов.

# %%
overall_funding_median = train['funding_total_usd'].median()
overall_funding_median
# Out:
# 2000000.0

# %%
def fill_missing_with_median(series):
    median = series.median()
    return series.fillna(median if not pd.isna(median) else overall_funding_median)

# %%
train['funding_total_usd'] = train.groupby('category_list')['funding_total_usd'].transform(fill_missing_with_median)

# %%
display(
    f"Процент пропусков в funding_total_usd: "
    f"{(train['funding_total_usd'].isna().sum() / len(train) * 100):.2f}%"
)
# Out:
# 'Процент пропусков в funding_total_usd: 0.00%'

# %%
train.isna().sum()
# Out:
# name                        0
# category_list               0
# funding_total_usd           0
# status                      0
# country_code                0
# state_code                  0
# region                      0
# city                        0
# funding_rounds              0
# founded_at                  0
# first_funding_at            0
# last_funding_at             0
# closed_at               47582
# category_first              0
# founded_at_year             0
# founded_at_month            0
# founded_at_day              0
# founded_at_dayofweek        0
# dtype: int64

# %% [markdown]
# ### Пропуски test

# %% [markdown]
# #### country

# %% [markdown]
# Аналогично используем RandomForest для заполнения пропусков Страны, а затем также используем функцию заполнения модой для столбцов Регион и Город.

# %%
features = test.drop(columns=['name',
                               'country_code',
                                'state_code',
                                'region',
                                'city',
                                'funding_total_usd'], axis=1).select_dtypes(include=[np.number])
target = test['country_code']

# %%
# Разделение на тренировочный и тестовый наборы
X_train = features[target.notna()]
y_train = target[target.notna()]
X_test = features[target.isna()]

# %%
# Модель
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Прогнозирование
predicted_countries = clf.predict(X_test)
np.array(np.unique(predicted_countries, return_counts=True)).T
# Out:
# array([['ARG', 2],
#        ['AUS', 16],
#        ['AUT', 4],
#        ['BEL', 4],
#        ['BGR', 1],
#        ['BRA', 13],
#        ['CAN', 25],
#        ['CHE', 2],
#        ['CHL', 6],
#        ['CHN', 26],
#        ['COL', 1],
#        ['CYM', 1],
#        ['CZE', 1],
#        ['DEU', 13],
#        ['DNK', 4],
#        ['ECU', 1],
#        ['ESP', 10],
#        ['EST', 2],
#        ['FIN', 5],
#        ['FRA', 18],
#        ['GBR', 48],
#        ['HKG', 5],
#        ['HRV', 1],
#        ['IND', 20],
#        ['IRL', 6],
#        ['ISR', 7],
#        ['ITA', 13],
#        ['JPN', 15],
#        ['KOR', 2],
#        ['LUX', 1],
#        ['MEX', 1],
#        ['NGA', 1],
#        ['NLD', 9],
#        ['NOR', 1],
#        ['NZL', 2],
#        ['PER', 1],
#        ['PHL', 2],
#        ['POL', 2],
#        ['PRT', 1],
#        ['ROM', 2],
#        ['RUS', 15],
#        ['SGP', 6],
#        ['SVK', 1],
#        ['SWE', 3],
#        ['TUR', 5],
#        ['UKR', 3],
#        ['USA', 1054]], dtype=object)

# %%
test.loc[test['country_code'].isna(), 'country_code'] = predicted_countries

# %%
test['state_code'] = test.groupby('country_code')['state_code'].transform(fill_missing_with_mode)
test['state_code'] = test['state_code'].fillna('nostate')
test['region'] = test.groupby('country_code')['region'].transform(fill_missing_with_mode)
test['city'] = test.groupby('region')['city'].transform(fill_missing_with_mode)

# %%
for column in columns_to_check:
    missing_percentage = (test[column].isna().sum() / len(test) * 100)
    display(f"Процент пропусков в {column}: {missing_percentage:.2f}%")
# Out:
# 'Процент пропусков в country_code: 0.00%'
# 'Процент пропусков в state_code: 0.00%'
# 'Процент пропусков в region: 0.03%'
# 'Процент пропусков в city: 0.03%'

# %%
display(test.shape)
display(sample.shape)
# Out:
# (13125, 12)
# (13125, 2)

# %%
# получить индексы, где city NaN
rows_with_nan = test[test['city'].isna()]
indices_to_remove = rows_with_nan.index

# удалить строки с этими индексами из test
test = test.drop(indices_to_remove)

# удалить строки sample
sample = sample.drop(indices_to_remove)

display(test.shape)
display(sample.shape)
# Out:
# (13121, 12)
# (13121, 2)

# %% [markdown]
# #### category

# %%
display('Количество пропусков')
display(test.isna().sum())
# Out:
# 'Количество пропусков'
# name                    0
# category_list         591
# funding_total_usd    2578
# country_code            0
# state_code              0
# region                  0
# city                    0
# funding_rounds          0
# first_funding_at        0
# last_funding_at         0
# lifetime                0
# category_first        591
# dtype: int64

# %%
test['category_list'] = test.groupby('country_code')['category_list'].transform(fill_missing_with_mode)
test['category_list'] = test['category_list'].fillna(test['category_list'].mode()[0])

# %% [markdown]
# #### funding_total_usd

# %%
test['funding_total_usd'] = test.groupby('category_list')['funding_total_usd'].transform(fill_missing_with_median)

# %% [markdown]
# ## Полноценный разведочный анализ

# %%
train.hist(figsize=(20, 20));

# %%
#создаем сводную таблицу, группируем строки по попродам
pivot_pie_status = train.pivot_table(index='status',
                              values='name',
                              aggfunc='count')

#по сводной таблице строим пайчарт
plt.pie(pivot_pie_status['name'], labels=pivot_pie_status.index, autopct='%.1f', colors=plt.cm.Pastel1.colors)
plt.title('Соотношение целевого признака')
plt.show()

# %% [markdown]
# ### Страны и регионы

# %%
pivot_pie_country = train.pivot_table(index='country_code',
                              values='name',
                              aggfunc='count').sort_values(by=['name'], ascending=False).head(10)

plt.pie(pivot_pie_country['name'], labels=pivot_pie_country.index, autopct='%.1f', colors=plt.cm.Pastel1.colors)
plt.title('Соотношение стран')
plt.show()

# %%
pivot_pie_country = train.pivot_table(index='state_code',
                              values='name',
                              aggfunc='count').sort_values(by=['name'], ascending=False).head(10)

plt.pie(pivot_pie_country['name'], labels=pivot_pie_country.index, autopct='%.1f', colors=plt.cm.Pastel1.colors)
plt.title('Соотношение штатов')
plt.show()

# %%
pivot_pie_country = train.pivot_table(index='region',
                              values='name',
                              aggfunc='count').sort_values(by=['name'], ascending=False).head(10)

plt.pie(pivot_pie_country['name'], labels=pivot_pie_country.index, autopct='%.1f', colors=plt.cm.Pastel1.colors)
plt.title('Соотношение регионов')
plt.show()

# %%
pivot_pie_country = train.pivot_table(index='city',
                              values='name',
                              aggfunc='count').sort_values(by=['name'], ascending=False).head(10)

plt.pie(pivot_pie_country['name'], labels=pivot_pie_country.index, autopct='%.1f', colors=plt.cm.Pastel1.colors)
plt.title('Соотношение городов')
plt.show()

# %% [markdown]
# ### Категории

# %%
train['category_list'].value_counts(ascending=True).tail(30).plot.barh(figsize = (16, 12))
#plt.title('Распределение по пастбищам')
#plt.xlabel("Число особей")
plt.show()

# %%
train['country_code'].value_counts(ascending=False).head(9)
# Out:
# country_code
# USA    34664
# GBR     3031
# CAN     1576
# IND     1335
# CHN     1283
# FRA      951
# DEU      874
# ISR      776
# ESP      627
# Name: count, dtype: int64

# %%
top_countries = train['country_code'].value_counts(ascending=False).head(9).index

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15))
axes = axes.flatten()

for i, country in enumerate(top_countries):
    pivot_pie_country = train[train['country_code'] == country].pivot_table(index='category_list',
                                                                           values='name',
                                                                           aggfunc='count').sort_values(by=['name'],
                                                                                                        ascending=False).head(10)

    axes[i].pie(pivot_pie_country['name'], labels=pivot_pie_country.index, autopct='%.1f', colors=plt.cm.Pastel1.colors)
    axes[i].set_title(f'{country}')

plt.tight_layout()
plt.show()

# %% [markdown]
# В каждой стране свое соотношение технологий.

# %% [markdown]
# ### Объем финансирования

# %%
train['funding_total_usd'].hist(figsize = (16, 4), bins=50)
#plt.title('Удой, кг')
#plt.xlabel('кг')
#plt.ylabel('Число особей')
plt.show()

# %%
train.boxplot(column="funding_total_usd",figsize = (16, 2), vert=False)
plt.title('funding_total_usd')
plt.show()

# %%
display(train[train['funding_total_usd']>5000000000])
# Out:
#                                       name  \
# 4557                                  Uber
# 5287   Cambridge Technology Partners (CTP)
# 15976                            Clearwire
# 21241           Cambridge Technology Group
# 29080               Charter Communications
# 36634                             Sberbank
# 39186               Verizon Communications
#
#                                            category_list  funding_total_usd  \
# 4557   Automotive|Design|Limousines|Public Transporta...       8.207450e+09
# 5287                        Architecture|Banking|Finance       5.150000e+09
# 15976                                    Internet|Mobile       5.820000e+09
# 21241  Consulting|Product Development Services|Produc...       1.066494e+10
# 29080       Internet|Telecommunications|Television|Video       5.162513e+09
# 36634                                    Banking|Finance       5.800000e+09
# 39186  Communications Infrastructure|Information Tech...       3.007950e+10
#
#           status country_code state_code         region           city  \
# 4557   operating          USA         CA    SF Bay Area  San Francisco
# 5287   operating          USA         CA    SF Bay Area  San Francisco
# 15976  operating          USA         WA        Seattle       Kirkland
# 21241  operating          USA         CA    SF Bay Area  San Francisco
# 29080  operating          USA         CT       Hartford       Stamford
# 36634  operating          RUS         48         Moscow         Moscow
# 39186  operating          USA         NY  New York City       New York
#
#        funding_rounds founded_at first_funding_at last_funding_at closed_at  \
# 4557               13 2009-03-01       2009-08-01      2015-09-07       NaT
# 5287                2 1990-01-11       1995-01-01      2001-01-01       NaT
# 15976               6 2003-10-01       2001-12-11      2013-02-27       NaT
# 21241               1 1988-01-01       2000-01-01      2000-01-01       NaT
# 29080               2 1993-01-01       2009-11-21      2014-09-15       NaT
# 36634               1 2013-03-20       2014-07-07      2014-07-07       NaT
# 39186               5 1983-10-07       2010-01-26      2014-02-28       NaT
#
#                       category_first  founded_at_year  founded_at_month  \
# 4557                      Automotive             2009                 3
# 5287                    Architecture             1990                 1
# 15976                       Internet             2003                10
# 21241                     Consulting             1988                 1
# 29080                       Internet             1993                 1
# 36634                        Banking             2013                 3
# 39186  Communications Infrastructure             1983                10
#
#        founded_at_day  founded_at_dayofweek
# 4557                1                     6
# 5287               11                     3
# 15976               1                     2
# 21241               1                     4
# 29080               1                     4
# 36634              20                     2
# 39186               7                     4

# %%
Q1 = train['funding_total_usd'].quantile(0.25)
Q3 = train['funding_total_usd'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = (Q1 - 1.5 * IQR)
upper_bound = (Q3 + 1.5 * IQR)

# %%
without_outlier = train[(train['funding_total_usd'] > lower_bound ) & (train['funding_total_usd'] < upper_bound)]

# %%
plt.rcParams['figure.figsize'] = 15,6
plt.hist(without_outlier['funding_total_usd'].dropna(), bins=30)

plt.ylabel('Число стартапов')
plt.xlabel('Инвестиции (usd)')
plt.title("Распределение инвестиций между первым и третьим квантилем", fontdict=None, position= [0.48,1.05], size = 'x-large')
plt.show()

# %% [markdown]
# Распределение целевого признака показало явный дисбаланс целевого признака 90 к 10 процентам. Таким образом модель может ошибаться склоняясь к преобладающему признаку.
#
# Число стартапов с раундами финансирования сильнопадает после 4-5 раундов.
#
# Почти все стартапы образовались после 1990 года, большая часть после 2000.
#
# Больше всего стартапов закрылось в 2012 году.
#
# В промежутке с 1995 до 2000 начался резкий рост количества стартапов.
#
# Дату основания стартапа как правило выставляют на ровную дату 01.01. Остальные месяцы и дни, дни недели распределены одинаково.
#
# Среди стран большой перевес у USA 76% (больше всего стартапов в штате Калифорния 53%, SF Bay Area, San Francisco).
#
# Великобритания 7%, Канада 3,5%, Индия 2,9%, Китай 2.8%.
#
# Больше всего стартапов в категории Software, Biotechnology, E-commerce, Mobile, Games, Education. Хотя в каждой стране свое распределение категорий, эти категории лидируют везде.
# Большая часть стартапов получает минимальные инвестиции. При этом существуют выбросы известные на весь мир стартапы типа Убер. Инвестиции в такие стартапы превышают 5 000 000 000 долларов и они все действующие. Не удаляем их.

# %% [markdown]
# ## Разработка новых синтетических признаков

# %% [markdown]
# ### lifetime

# %% [markdown]
# В тестовой выборке отсутствует столбец с датой закрытия, но есть столбец с длительностью жизни. Создадим такой столбец в тренировочном датафрейме.

# %%
train.columns
# Out:
# Index(['name', 'category_list', 'funding_total_usd', 'status', 'country_code',
#        'state_code', 'region', 'city', 'funding_rounds', 'founded_at',
#        'first_funding_at', 'last_funding_at', 'closed_at', 'category_first',
#        'founded_at_year', 'founded_at_month', 'founded_at_day',
#        'founded_at_dayofweek'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['name', 'category_list', 'funding_total_usd', 'country_code',
#        'state_code', 'region', 'city', 'funding_rounds', 'first_funding_at',
#        'last_funding_at', 'lifetime', 'category_first'],
#       dtype='object')

# %%
train['last_date'] = train['closed_at']
train[['last_date','closed_at']].head(25)
# Out:
#     last_date  closed_at
# 0         NaT        NaT
# 1         NaT        NaT
# 2         NaT        NaT
# 3         NaT        NaT
# 4         NaT        NaT
# 5         NaT        NaT
# 6         NaT        NaT
# 7         NaT        NaT
# 8         NaT        NaT
# 9         NaT        NaT
# 10        NaT        NaT
# 11        NaT        NaT
# 12 2015-07-10 2015-07-10
# 13        NaT        NaT
# 14        NaT        NaT
# 15        NaT        NaT
# 16 2015-08-11 2015-08-11
# 17        NaT        NaT
# 18        NaT        NaT
# 19        NaT        NaT
# 20        NaT        NaT
# 21        NaT        NaT
# 22        NaT        NaT
# 23 2014-09-04 2014-09-04
# 24 2016-11-03 2016-11-03

# %%
train['last_date'] = train['last_date'].fillna('2018-01-01')
train[['last_date','closed_at']].head(25)
# Out:
#     last_date  closed_at
# 0  2018-01-01        NaT
# 1  2018-01-01        NaT
# 2  2018-01-01        NaT
# 3  2018-01-01        NaT
# 4  2018-01-01        NaT
# 5  2018-01-01        NaT
# 6  2018-01-01        NaT
# 7  2018-01-01        NaT
# 8  2018-01-01        NaT
# 9  2018-01-01        NaT
# 10 2018-01-01        NaT
# 11 2018-01-01        NaT
# 12 2015-07-10 2015-07-10
# 13 2018-01-01        NaT
# 14 2018-01-01        NaT
# 15 2018-01-01        NaT
# 16 2015-08-11 2015-08-11
# 17 2018-01-01        NaT
# 18 2018-01-01        NaT
# 19 2018-01-01        NaT
# 20 2018-01-01        NaT
# 21 2018-01-01        NaT
# 22 2018-01-01        NaT
# 23 2014-09-04 2014-09-04
# 24 2016-11-03 2016-11-03

# %%
train['lifetime'] = (train['last_date'] - train['founded_at']).dt.days
train[['founded_at', 'last_date', 'lifetime', 'closed_at']].head(5)
# Out:
#   founded_at  last_date  lifetime closed_at
# 0 2009-10-17 2018-01-01      2998       NaT
# 1 2005-01-01 2018-01-01      4748       NaT
# 2 2006-01-01 2018-01-01      4383       NaT
# 3 2004-01-01 2018-01-01      5114       NaT
# 4 2010-05-12 2018-01-01      2791       NaT

# %%
test['lifetime']
# Out:
# 1        2717
# 2        1295
# 3        4748
# 4        6209
# 5        1583
#          ...
# 13120    2267
# 13121    2192
# 13122    2922
# 13123    1386
# 13124    5479
# Name: lifetime, Length: 13121, dtype: int64

# %% [markdown]
# ### funding dates

# %%
train['first_funding_at_year'] = train['first_funding_at'].dt.year
train['first_funding_at_month'] = train['first_funding_at'].dt.month
train['first_funding_at_day'] = train['first_funding_at'].dt.year
train['first_funding_at_dayofweek'] = train['first_funding_at'].dt.year

train['last_funding_at_year'] = train['last_funding_at'].dt.year
train['last_funding_at_month'] = train['last_funding_at'].dt.month
train['last_funding_at_day'] = train['last_funding_at'].dt.year
train['last_funding_at_dayofweek'] = train['last_funding_at'].dt.year

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13121 entries, 1 to 13124
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13121 non-null  object
#  1   category_list      13121 non-null  object
#  2   funding_total_usd  13121 non-null  float64
#  3   country_code       13121 non-null  object
#  4   state_code         13121 non-null  object
#  5   region             13121 non-null  object
#  6   city               13121 non-null  object
#  7   funding_rounds     13121 non-null  int64
#  8   first_funding_at   13121 non-null  datetime64[ns]
#  9   last_funding_at    13121 non-null  datetime64[ns]
#  10  lifetime           13121 non-null  int64
#  11  category_first     12530 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(7)
# memory usage: 1.3+ MB

# %%
test['first_funding_at_year'] = test['first_funding_at'].dt.year
test['first_funding_at_month'] = test['first_funding_at'].dt.month
test['first_funding_at_day'] = test['first_funding_at'].dt.year
test['first_funding_at_dayofweek'] = test['first_funding_at'].dt.year

test['last_funding_at_year'] = test['last_funding_at'].dt.year
test['last_funding_at_month'] = test['last_funding_at'].dt.month
test['last_funding_at_day'] = test['last_funding_at'].dt.year
test['last_funding_at_dayofweek'] = test['last_funding_at'].dt.year

# %% [markdown]
# ### city_is_capital

# %%
capitals = ['Bern', 'Washington, D.C.', 'London', 'Moscow', 'Madrid', 'Paris', 'Stockholm', 'New Delhi', 'Seoul',
            'Canberra', 'Taipei', 'Beijing', 'Budapest', 'Ottawa', 'Helsinki', 'Brasília', 'Cairo', 'Lisbon',
            'Jerusalem', 'Santiago', 'Bratislava', 'Amsterdam', 'Buenos Aires', 'Abu Dhabi', 'Tokyo', 'Dublin',
            'Berlin', 'Beirut', 'Tallinn', 'Jakarta', 'Brussels', 'Mexico City', 'Copenhagen', 'Rome', 'Athens',
            'Bucharest', 'Ankara', 'Singapore', 'Riyadh', 'Kuala Lumpur', 'Lagos', 'Doha', 'Hanoi', 'Sofia',
            'Accra', 'Kampala', 'Amman', 'Vienna', 'Islamabad', 'Wellington', 'Hong Kong', 'Pretoria', 'Riga',
            'Oslo', 'Zagreb', 'Caracas', 'Lima', 'Luxembourg', 'Ljubljana', 'Warsaw', 'Manila', 'Managua',
            'Prague', 'Reykjavik', 'Panama City', 'Montevideo', 'Dhaka', 'Monaco', 'Guatemala City', 'Bangkok',
            'Port of Spain', 'Kyiv', 'Nairobi', 'San José', 'Algiers', 'Vilnius', 'George Town', 'Port Louis',
            'Minsk', 'San Salvador', 'Bogotá', 'Valletta', 'Ramallah', 'Belmopan', 'Nicosia', 'Naypyidaw',
            'Skopje', 'Phnom Penh', 'Gibraltar', 'Belgrade', 'Santo Domingo', 'Gaborone', 'Gustavia', 'Asunción',
            'Hamilton', 'Dodoma', 'Vaduz', "Saint George's", 'Tashkent', 'Tbilisi', 'Dakar', 'Tirana', 'Quito',
            'Maputo', 'Colombo', 'Vientiane', 'Tunis', 'Tegucigalpa', 'Harare', 'Nassau', 'Chisinau', 'Marigot',
            'Manama', 'Baku', 'Rabat', 'Kuwait City', 'Tehran', 'Saint Peter Port', 'Basseterre', 'San Juan',
            'Muscat', 'Nur-Sultan', 'Kingston', 'Kathmandu', 'Yerevan', 'Lomé', 'Kigali', 'Bandar Seri Begawan',
            'Saint Helier', 'Mogadishu', 'Yaoundé', 'Podgorica', 'Victoria', 'Lusaka']

# %%
train['city_is_capital'] = train['city'].apply(lambda x: 1 if x in capitals else 0)
train[['city','city_is_capital']].head(3)
# Out:
#            city  city_is_capital
# 0        Zürich                0
# 1  Redwood City                0
# 2      San Jose                0

# %%
test['city_is_capital'] = test['city'].apply(lambda x: 1 if x in capitals else 0)
test[['city','city_is_capital']].head(3)
# Out:
#                city  city_is_capital
# 1          Humboldt                0
# 2  Esch-sur-alzette                0
# 3         San Diego                0

# %% [markdown]
# ## Проверка на мультиколлинеарность

# %% [markdown]
# Для подсчета корреляций закодируем категории

# %%
# Создание экземпляра OneHotEncoder
encoder = OneHotEncoder(sparse_output=False)

# Кодирование столбца 'status'
status_encoded = encoder.fit_transform(train[['status']])
status_encoded_df = pd.DataFrame(status_encoded, columns=encoder.get_feature_names_out(['status']))

# Объединение закодированных столбцов с исходным DataFrame
train_encoded = pd.concat([train, status_encoded_df], axis=1)

# Удаление исходных столбцов 'status' и 'continent'
train_encoded.drop(['status'], axis=1, inplace=True)

# %%
columns_to_drop = ['name',
                   'category_list',
                   'category_first',
                   'country_code',
                   'state_code',
                   'region',
                   'city',
                   'founded_at',
                   'first_funding_at',
                   'last_funding_at',
                   'closed_at']

corr_matrix_train = train_encoded.drop(columns=columns_to_drop).corr()

# Визуализация корреляции пропусков
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix_train, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 5})
plt.title('Корреляция между столбцами')
plt.show()

# %% [markdown]
# Есть высокие значения корреляции. Чтобы избежать мультиколлинеарности, добавим в список для удаления столбцы:

# %%
columns_to_drop = ['name',
                   'category_list',
                   'state_code',
                   'region',
                   'city',
                   'founded_at',
                   'founded_at_year',
                   'founded_at_month',
                   'founded_at_day',
                   'founded_at_dayofweek',
                   'first_funding_at',
                   'first_funding_at_day',
                   'first_funding_at_dayofweek',
                   'last_funding_at_day',
                   'last_funding_at_dayofweek',
                   'last_funding_at_month',
                   'last_funding_at_year',
                   'last_funding_at',
                   'closed_at',
                   'last_date',
                  'status']

# %% [markdown]
# ## Отбор финального набора обучающих признаков

# %%
# создание константы RANDOM_STATE
RANDOM_STATE = 42

# %%
X_train = train.drop(columns_to_drop, axis=1)
X_train.columns
# Out:
# Index(['funding_total_usd', 'country_code', 'funding_rounds', 'category_first',
#        'lifetime', 'first_funding_at_year', 'first_funding_at_month',
#        'city_is_capital'],
#       dtype='object')

# %%
X_test = test.drop(['name',
                   'category_list',
                   'state_code',
                   'region',
                   'city',
                   'first_funding_at',
                   'first_funding_at_day',
                   'first_funding_at_dayofweek',
                   'last_funding_at_day',
                   'last_funding_at_dayofweek',
                   'last_funding_at_month',
                   'last_funding_at_year',
                   'last_funding_at'
                   ], axis=1)
X_test.columns
# Out:
# Index(['funding_total_usd', 'country_code', 'funding_rounds', 'lifetime',
#        'category_first', 'first_funding_at_year', 'first_funding_at_month',
#        'city_is_capital'],
#       dtype='object')

# %%
y_train = train['status']
y_test = sample['status']

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
ohe_columns = ['category_first','country_code','city_is_capital']
ord_columns = []
num_columns = ['funding_total_usd', 'funding_rounds',
               'lifetime','first_funding_at_month']

# %% [markdown]
# ## Выбор и обучение моделей

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns:
ohe_pipe = Pipeline(
    [
        ('ohe', OneHotEncoder(drop='first',
                              handle_unknown='ignore',
                              sparse_output=False))
    ]
)

ord_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder(
        handle_unknown='use_encoded_value',
        unknown_value = np.nan))
])

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', OrdinalEncoder(), ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ],
    remainder='passthrough'
)

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %%
param_distributions = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    # словарь для модели CatBoostClassifier()
    {
        'models': [CatBoostClassifier(random_state=RANDOM_STATE, silent=True, task_type='GPU')],
        'models__depth': range(2, 5),
        'models__iterations': [50, 100],
        'models__learning_rate': [0.01, 0.1],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %%
'''
# с регуляризацией -- показало меньшую оценку на трейне и на тесте
param_distributions = [
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__min_samples_split': [2, 5, 10],
        'models__min_samples_leaf': [1, 2, 4],
        'models__ccp_alpha': [0.0, 0.01, 0.1],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [CatBoostClassifier(random_state=RANDOM_STATE, silent=True, task_type='GPU')],
        'models__depth': range(2, 5),
        'models__l2_leaf_reg': [1, 3, 5],
        'models__random_strength': [0.5, 1, 2],
        'models__bagging_temperature': [0, 1, 2],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]
'''
# Out:
# "\n# с регуляризацией -- показало меньшую оценку на трейне и на тесте\nparam_distributions = [\n    {\n        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],\n        'models__max_depth': range(2, 5),\n        'models__min_samples_split': [2, 5, 10],\n        'models__min_samples_leaf': [1, 2, 4],\n        'models__ccp_alpha': [0.0, 0.01, 0.1],\n        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']\n    },\n    {\n        'models': [CatBoostClassifier(random_state=RANDOM_STATE, silent=True, task_type='GPU')],\n        'models__depth': range(2, 5),\n        'models__l2_leaf_reg': [1, 3, 5],\n        'models__random_strength': [0.5, 1, 2],\n        'models__bagging_temperature': [0, 1, 2],\n        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']\n    }\n]\n"

# %%
joblib.parallel_backend('threading')

# %%
#запускаем таймер
start = time.time()

random_search = RandomizedSearchCV(
    pipe_final,
    param_distributions=param_distributions,
    n_iter=10,  # количество итераций поиска
    cv=5,
    scoring='f1',
    verbose=10,
    n_jobs=-1,
    random_state=RANDOM_STATE
)

random_search.fit(X_train, y_train_encoded)

search_time = (time.time() - start)/60
print(f'Время поиска: {search_time:.1f} мин')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 2/5; 1/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 3/5; 1/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 4/5; 1/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 5/5; 1/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 1/5; 2/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler()
# [CV 2/5; 2/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler()
# [CV 3/5; 2/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler()
# [CV 4/5; 2/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler()
# [CV 5/5; 2/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler()
# [CV 1/5; 3/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler()
# [CV 2/5; 3/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler()
# [CV 3/5; 3/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler()
# [CV 4/5; 3/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler()
# [CV 5/5; 3/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler()
# [CV 1/5; 4/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 3/5; 2/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler();, score=nan total time=  31.8s
# [CV 2/5; 4/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 1/5; 2/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler();, score=nan total time=  31.8s
# [CV 3/5; 4/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 4/5; 1/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=nan total time= 1.1min
# [CV 4/5; 4/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 1/5; 1/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=nan total time=  31.8s
# [CV 5/5; 4/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler()
# [CV 3/5; 1/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=nan total time= 1.2min
# [CV 1/5; 5/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough
# [CV 5/5; 2/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler();, score=nan total time= 1.2min
# [CV 2/5; 5/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough
# [CV 2/5; 2/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler();, score=nan total time= 1.3min
# [CV 3/5; 5/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough
# [CV 2/5; 1/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=nan total time= 1.3min
# [CV 4/5; 5/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [CV 5/5; 1/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=0.987 total time= 1.4min
# [CV 5/5; 5/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough
# [CV 2/5; 3/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler();, score=0.951 total time= 1.4min
# [CV 1/5; 6/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 3/5; 3/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler();, score=0.951 total time= 1.4min
# [CV 2/5; 6/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 4/5; 2/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.01, preprocessor__num=StandardScaler();, score=0.982 total time= 1.4min
# [CV 3/5; 6/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 4/5; 3/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler();, score=0.951 total time= 1.4min
# [CV 4/5; 6/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 1/5; 3/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler();, score=0.951 total time= 1.4min
# [CV 5/5; 6/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 5/5; 3/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=2, preprocessor__num=StandardScaler();, score=0.951 total time= 1.7min
# [CV 1/5; 7/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler()
# [CV 4/5; 4/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=nan total time=  19.3s
# [CV 2/5; 7/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler()
# [CV 3/5; 4/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=nan total time=  19.4s
# [CV 3/5; 7/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler()
# [CV 5/5; 4/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=nan total time=  31.5s
# [CV 4/5; 7/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler()
# [CV 2/5; 4/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=nan total time= 1.3min
# [CV 5/5; 7/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler()
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [CV 1/5; 4/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=3, models__iterations=50, models__learning_rate=0.1, preprocessor__num=MinMaxScaler();, score=0.985 total time= 1.9min
# [CV 1/5; 8/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler()
# [CV 5/5; 6/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=nan total time=  52.9s[CV 1/5; 6/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=nan total time=  46.5s
# [CV 2/5; 8/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler()
#
# [CV 3/5; 8/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler()
# [CV 4/5; 6/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=nan total time=  59.5s
# [CV 4/5; 8/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler()
# [CV 2/5; 6/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=nan total time=  59.5s
# [CV 5/5; 8/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler()
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [CV 1/5; 5/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough;, score=0.951 total time= 1.1min
# [CV 1/5; 9/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler()
# [CV 3/5; 5/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough;, score=0.951 total time= 1.1min
# [CV 2/5; 9/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler()
# [CV 2/5; 5/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough;, score=0.951 total time= 1.1min
# [CV 3/5; 9/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler()
# [CV 4/5; 5/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough;, score=0.951 total time= 1.1min
# [CV 4/5; 9/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler()
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [CV 5/5; 5/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=2, models__max_features=3, preprocessor__num=passthrough;, score=0.951 total time= 1.0min
# [CV 5/5; 9/10] START models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler()
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [CV 1/5; 7/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=  42.3s
# [CV 1/5; 10/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 2/5; 7/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=  36.4s
# [CV 2/5; 10/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 4/5; 7/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=  36.3s
# [CV 3/5; 10/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [CV 3/5; 7/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=  36.5s
# [CV 4/5; 10/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 5/5; 7/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=  36.5s
# [CV 5/5; 10/10] START models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler()
# [CV 3/5; 6/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=2, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=0.984 total time= 1.1min
# [CV 1/5; 8/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler();, score=0.951 total time=  36.3s
# [CV 3/5; 8/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler();, score=0.951 total time=   3.9s
# [CV 5/5; 8/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler();, score=0.951 total time=   3.9s
# [CV 4/5; 8/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler();, score=0.951 total time=   4.0s
# [CV 2/5; 8/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=3, models__max_features=3, preprocessor__num=StandardScaler();, score=0.951 total time=   4.1s
# [CV 3/5; 9/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=   3.7s
# [CV 1/5; 9/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=   3.7s
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [CV 2/5; 9/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=  23.9s
# [CV 2/5; 10/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=nan total time=  20.7s
# [CV 3/5; 10/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=nan total time=  20.7s
# [CV 4/5; 9/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=  23.8s
# [CV 4/5; 10/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=nan total time=  35.1s
# [CV 5/5; 10/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=nan total time=  35.1s
# [CV 5/5; 9/10] END models=DecisionTreeClassifier(random_state=42), models__max_depth=4, models__max_features=4, preprocessor__num=MinMaxScaler();, score=0.951 total time=  37.9s
# [CV 1/5; 10/10] END models=<catboost.core.CatBoostClassifier object at 0x00000146AD542750>, models__depth=4, models__iterations=100, models__learning_rate=0.1, preprocessor__num=StandardScaler();, score=0.986 total time=  35.4s
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 20 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\User\anaconda3\Lib\site-packages\catboost\core.py", line 5220, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\User\anaconda3\Lib\site-packages\catboost\core.py", line 2400, in _fit
#     self._train(
#   File "C:\Users\User\anaconda3\Lib\site-packages\catboost\core.py", line 1780, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4833, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4882, in _catboost._CatBoost._train
# _catboost.CatBoostError: C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/cuda/cuda_lib/devices_provider.h:190: Error: device already requested 0
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\User\anaconda3\Lib\site-packages\catboost\core.py", line 5220, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\User\anaconda3\Lib\site-packages\catboost\core.py", line 2400, in _fit
#     self._train(
#   File "C:\Users\User\anaconda3\Lib\site-packages\catboost\core.py", line 1780, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4833, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4882, in _catboost._CatBoost._train
# _catboost.CatBoostError: C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/cuda/cuda_lib/cuda_manager.cpp:201: Condition violated: `State == nullptr'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.95084883        nan 0.9508793         nan
#  0.95084883 0.9508983  0.9508698         nan]
#   warnings.warn(
# Время поиска: 3.1 мин

# %% [markdown]
# ## Итоговая оценка качества предсказания лучшей модели

# %%
print('Лучшая модель и её параметры:\n\n', random_search.best_estimator_)
print('Метрика лучшей модели на тренировочной выборке:', random_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['category_first',
#                                                    'country_code',
#                                                    'city_is_capital']),
#                                                  ('ord', OrdinalEncoder(), []),
#                                                  ('num', StandardScaler(),
#                                                   ['funding_total_usd',
#                                                    'funding_rounds', 'lifetime',
#                                                    'first_funding_at_month'])])),
#                 ('models',
#                  DecisionTreeClassifier(max_depth=3, max_features=3,
#                                         random_state=42))])
# Метрика лучшей модели на тренировочной выборке: 0.9508983008982794

# %%
y_pred = random_search.predict(X_test)
y_pred_encoded = label_encoder.inverse_transform(y_pred)

print(f'Метрика F1 на тестовой выборке: {f1_score(y_test_encoded, y_pred)}')
# Out:
# Метрика F1 на тестовой выборке: 0.6715601903411966
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y_pred_encoded
# Out:
# array(['operating', 'operating', 'operating', ..., 'operating',
#        'operating', 'operating'], dtype=object)

# %%
y_test_encoded
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# Выведем на экран график важности признаков обученной модели. Отсортируем признаки по убыванию значимости.
#
# Построим столбчатую диаграмму с помощью SHAP, покажем средний вклад каждого признака в результат работы модели.

# %%
'''
# Создаем объект KernelExplainer для лучшей модели
best_model = random_search.best_estimator_.named_steps['models']
preprocessor = random_search.best_estimator_.named_steps['preprocessor']
X_train_transformed = preprocessor.transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# Используем небольшое подмножество данных для создания Explainer (KernelExplainer может быть медленным)
X_train_sample = shap.sample(X_train_transformed, 100)

explainer = shap.KernelExplainer(best_model.predict, X_train_sample)
shap_values = explainer.shap_values(X_test_transformed, nsamples=100)

# Строим столбчатую диаграмму важности признаков
shap.summary_plot(shap_values, X_test_transformed, feature_names=X_train.columns, plot_type="bar")
'''
#IndexError: index 269 is out of bounds for axis 0 with size 8
# Time calculate over 9h
# Out:
# '\n# Создаем объект KernelExplainer для лучшей модели\nbest_model = random_search.best_estimator_.named_steps[\'models\']\npreprocessor = random_search.best_estimator_.named_steps[\'preprocessor\']\nX_train_transformed = preprocessor.transform(X_train)\nX_test_transformed = preprocessor.transform(X_test)\n\n# Используем небольшое подмножество данных для создания Explainer (KernelExplainer может быть медленным)\nX_train_sample = shap.sample(X_train_transformed, 100)\n\nexplainer = shap.KernelExplainer(best_model.predict, X_train_sample)\nshap_values = explainer.shap_values(X_test_transformed, nsamples=100)\n\n# Строим столбчатую диаграмму важности признаков\nshap.summary_plot(shap_values, X_test_transformed, feature_names=X_train.columns, plot_type="bar")\n'

# %%
# Создаем объект TreeExplainer для лучшей модели
best_model = random_search.best_estimator_.named_steps['models']
preprocessor = random_search.best_estimator_.named_steps['preprocessor']
X_train_transformed = preprocessor.transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

# Создаем TreeExplainer
explainer = shap.TreeExplainer(best_model)

# Вычисляем SHAP значения
shap_values = explainer.shap_values(X_test_transformed)

# Проверяем размерности SHAP значений
print("Размерности shap_values:", shap_values.shape)

# Строим столбчатую диаграмму важности признаков
shap.summary_plot(shap_values, X_test_transformed, feature_names=X_train.columns, plot_type="bar")
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Размерности shap_values: (13121, 840, 2)

# %%
shap.summary_plot(shap_values, X_test_transformed, feature_names=X_train.columns)

# %%
shap_values
# Out:
# array([[[ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00],
#         [-7.66886762e-06,  7.66886762e-06],
#         [ 0.00000000e+00,  0.00000000e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00],
#         [-7.66886762e-06,  7.66886762e-06],
#         [ 0.00000000e+00,  0.00000000e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00],
#         [-7.66886762e-06,  7.66886762e-06],
#         [ 0.00000000e+00,  0.00000000e+00]],
#
#        ...,
#
#        [[ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00],
#         [-7.66886762e-06,  7.66886762e-06],
#         [ 0.00000000e+00,  0.00000000e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00],
#         [-7.66886762e-06,  7.66886762e-06],
#         [ 0.00000000e+00,  0.00000000e+00]],
#
#        [[ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00],
#         [-7.66886762e-06,  7.66886762e-06],
#         [ 0.00000000e+00,  0.00000000e+00]]])

# %%
# Вывод размерностей
print("Shape of feature_names:", feature_names.shape)
print("Shape of shap_importance:", shap_importance.shape)
# Out:
# Shape of feature_names: (840,)
# Shape of shap_importance: (840, 2)

# %%
# Усредняем значения SHAP по второй оси (если многоклассовая задача, усредняем по классам)
shap_importance_mean = np.mean(shap_importance, axis=1)

# Теперь размеры должны совпадать
shap_importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': shap_importance_mean
})

shap_importance_df = shap_importance_df.sort_values(by='importance', ascending=False)
print(shap_importance_df.head(10))
# Out:
#                                                feature  importance
# 176                   ohe__category_first_DOD/Military    0.000064
# 577                    ohe__category_first_Restaurants    0.000061
# 328  ohe__category_first_Health Care Information Te...    0.000040
# 838                        num__first_funding_at_month    0.000031
# 827                              ohe__country_code_USA    0.000010
# 761                              ohe__country_code_ITA    0.000002
# 573                 ohe__category_first_Renewable Tech    0.000000
# 561                           ohe__category_first_RFID    0.000000
# 553            ohe__category_first_Property Management    0.000000
# 554                     ohe__category_first_Psychology    0.000000

# %% [markdown]
# # Итог

# %% [markdown]
# С использованием пайплайна была получена лучшая модель с параметрами

# %%
print('Лучшая модель и её параметры:\n\n', random_search.best_estimator_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['category_first',
#                                                    'country_code',
#                                                    'city_is_capital']),
#                                                  ('ord', OrdinalEncoder(), []),
#                                                  ('num', StandardScaler(),
#                                                   ['funding_total_usd',
#                                                    'funding_rounds', 'lifetime',
#                                                    'first_funding_at_month'])])),
#                 ('models',
#                  DecisionTreeClassifier(max_depth=3, max_features=3,
#                                         random_state=42))])

# %% [markdown]
# И лучшей метрикой на тренировочном датасете 0.95. Корреляционным анализом исключили переобучение. На тестовом датасете добились максимальной оценки 0.67
#
# Анализ признаков показал наиболее важными признаками признаки категорий, стран и объема финансирования. После кодирования наибольший вес имели признаки:ohe__category_first_DOD/Military,  ohe__category_first_Restaurant,   ohe__category_first_Health Ca,    num__first_funding_at_mo,     ohe__country_code,      ohe__country_cod00002
